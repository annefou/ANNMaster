# %%
install.packages("sp", repos = "http://cran.us.r-project.org")
# Out:
# Installing package into 'C:/Users/annefou/Documents/R/win-library/3.4'
# (as 'lib' is unspecified)
# package 'sp' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'sp'"
# The downloaded binary packages are in
# 	C:\Users\annefou\AppData\Local\Temp\RtmpQb9CCA\downloaded_packages

# %%
install.packages("rgdal", repos = "http://cran.us.r-project.org")
# Out:
# Installing package into 'C:/Users/annefou/Documents/R/win-library/3.4'
# (as 'lib' is unspecified)
# package 'rgdal' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\annefou\AppData\Local\Temp\Rtmpyamrkq\downloaded_packages

# %%
library(raster)
# Out:
# Loading required package: sp

# %%
library(rgdal)
# Out:
# Warning message:
# "package 'rgdal' was built under R version 3.4.4"rgdal: version: 1.2-18, (SVN revision 718)
#  Geospatial Data Abstraction Library extensions to R successfully loaded
#  Loaded GDAL runtime: GDAL 2.2.3, released 2017/11/20
#  Path to GDAL shared files: C:/Users/annefou/Documents/R/win-library/3.4/rgdal/gdal
#  GDAL binary built with GEOS: TRUE
#  Loaded PROJ.4 runtime: Rel. 4.9.3, 15 August 2016, [PJ_VERSION: 493]
#  Path to PROJ.4 shared files: C:/Users/annefou/Documents/R/win-library/3.4/rgdal/proj
#  Linking to sp version: 1.2-7

# %%
setwd("c:/Users/annefou/Documents/Github/ANNMaster")

# %%
Z_num9 <- raster("data/Micmac_full_equalised/Z_Num9_DeZoom2_STD-MALT.tif")

# %%
plot(Z_num9,
     main = "Z_num9_DeZoom2_STD-MALT")
# Out:
# Plot with title "Z_num9_DeZoom2_STD-MALT"

# %%
scaled4 <- raster("data/Micmac_full_equalised/Scaled4.tif")
plot(scaled4,
     main = "Scale4")
# Out:
# Plot with title "Scale4"

# %%
scaled16 <- raster("data/Micmac_full_equalised/Scaled16.tif")
plot(scaled16,
     main = "Scale16")
# Out:
# Plot with title "Scale16"
